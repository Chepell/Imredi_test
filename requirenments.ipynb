# %%
# !pip freeze > requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.2 kB ? eta -:--:--
#      -------------------------------------- 61.2/61.2 kB 821.3 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for cmdstanpy==1.2.0 from https://files.pythonhosted.org/packages/e8/e2/2ddc273e726680a3c816f9a05c6726d57d61820fa7ab4753ed282d0a8bbe/cmdstanpy-1.2.0-py3-none-any.whl.metadata
# ...
#   Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# ...
#   Obtaining dependency information for Cython==3.0.3 from https://files.pythonhosted.org/packages/39/5d/5ae976df4e368327864917a24f9dee7c8176de1b5b7044ee9903b8adb07a/Cython-3.0.3-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
# ...
